# %% [markdown]
# Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print(num, "is not a prime number")
else:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a prime number")
            break
    else:
        print(num, "is a prime number")
# Out:
# Enter a number: 22
# 22 is not a prime number

# %% [markdown]
# Exercise 2: Product of Random Numbers
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# Generate two random numbers between 1 and 10
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

# Ask the user for the product
answer = int(input(f"What is {num1} × {num2}? "))

# Check the answer
if answer == num1 * num2:
    print("Correct! Well done.")
else:
    print("Incorrect.")
    print("The correct answer is:", num1 * num2)
# Out:
# What is 3 × 6? 7
# Incorrect.
# The correct answer is: 18

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
odd_OR_even = input("enter what u want (odd) or (even) :   ")

for i in range(100,201):
  if odd_OR_even == "odd":
    if i % 2 != 0:
      print(i*i)

  elif odd_OR_even == "even":
    if i % 2 == 0:
      print(i*i)
# Out:
# enter what u want (odd) or (even) :   odd
# 10201
# 10609
# 11025
# 11449
# 11881
# 12321
# 12769
# 13225
# 13689
# 14161
# 14641
# 15129
# 15625
# 16129
# 16641
# 17161
# 17689
# 18225
# 18769
# 19321
# 19881
# 20449
# 21025
# 21609
# 22201
# 22801
# 23409
# 24025
# 24649
# 25281
# 25921
# 26569
# 27225
# 27889
# 28561
# 29241
# 29929
# 30625
# 31329
# 32041
# 32761
# 33489
# 34225
# 34969
# 35721
# 36481
# 37249
# 38025
# 38809
# 39601

# %% [markdown]
# Exercise 4:
# ✅ Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# Room charges per day: ₹2,000
# Doctor consultation fee (flat): ₹1,500
# Lab test charges: Based on the number of tests taken. Each test costs ₹300
# Medicine charges: Total cost of medicines provided
# Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# Stayed for 4 days
# Had 3 lab tests
# Had medicine charges of ₹2,400

# %%
stayed = int(input("enter the number of days you stayed. :  "))
labtest = int(input("enter the total number of lab tested :  "))
madiine_charge = int(input("enter the total madiine charge :  "))

Room_charges_per_day = 2000 * stayed
Doctor_consultation_feec = 1500
Lab_per_test_charges = 300 * labtest

Final_Bill = Room_charges_per_day + Doctor_consultation_feec+ Lab_per_test_charges + madiine_charge

if Final_Bill > 10000:
  print("Final_Bill = " , (Final_Bill / 100)*90)

else:
  print("Final_Bill = " , Final_Bill)
# Out:
# enter the number of days you stayed. :  4
# enter the total number of lab tested :  3
# enter the total madiine charge :  2400
# Final_Bill =  11520.0
